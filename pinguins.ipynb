# %%
import pandas as pd
import seaborn as sea

# %%
pinguin = pd.read_csv('dados\Anexo_pinguins-2.csv', sep=';')
pinguin
# Out:
#         Espece       Ilha  largura do bico  profundidade do bico  \
# 0       Adelie  Torgersen             39.1                  18.7
# 1       Adelie  Torgersen             39.5                  17.4
# 2       Adelie  Torgersen             40.3                  18.0
# 3       Adelie  Torgersen              NaN                   NaN
# 4       Adelie  Torgersen             36.7                  19.3
# ..         ...        ...              ...                   ...
# 339  Chinstrap      Dream             55.8                  19.8
# 340  Chinstrap      Dream             43.5                  18.1
# 341  Chinstrap      Dream             49.6                  18.2
# 342  Chinstrap      Dream             50.8                  19.0
# 343  Chinstrap      Dream             50.2                  18.7
#
#      profundidade do bico.1  massa corporal    sexo
# 0                     181.0          3750.0    male
# 1                     186.0          3800.0  female
# ...

# %%
pinguin.Espece.value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: Espece, dtype: int64

# %%
indices_com_nulos = pinguin[pinguin.isnull().any(axis=1)].index
indices_com_nulos
# Out:
# Int64Index([3, 8, 9, 10, 11, 47, 178, 218, 256, 268, 271], dtype='int64')

# %%
numero_de_linhas_com_nulos = pinguin.isnull().any(axis=1).sum()
numero_de_linhas_com_nulos
# Out:
# 11

# %%
sea.boxenplot(x='Espece', y='massa corporal', data=pinguin)
# Out:
# <AxesSubplot:xlabel='Espece', ylabel='massa corporal'>

# %%
pinguin.Espece.value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: Espece, dtype: int64

# %%
Adelie = pinguin[pinguin['Espece'] == 'Adelie']
Gentoo = pinguin[pinguin['Espece'] == 'Gentoo']
Chinstrap = pinguin[pinguin['Espece'] == 'Chinstrap']

# %%
sexo = pd.get_dummies(pinguin.sexo)
sexo
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         0     0
# 4         1     0
# ..      ...   ...
# 339       0     1
# 340       1     0
# 341       0     1
# 342       0     1
# 343       1     0
#
# [344 rows x 2 columns]

# %%
pinguin[['female', 'male']] = sexo
pinguin.head()
# Out:
#    Espece       Ilha  largura do bico  profundidade do bico  \
# 0  Adelie  Torgersen             39.1                  18.7
# 1  Adelie  Torgersen             39.5                  17.4
# 2  Adelie  Torgersen             40.3                  18.0
# 3  Adelie  Torgersen              NaN                   NaN
# 4  Adelie  Torgersen             36.7                  19.3
#
#    profundidade do bico.1  massa corporal    sexo  female  male
# 0                   181.0          3750.0    male       0     1
# 1                   186.0          3800.0  female       1     0
# 2                   195.0          3250.0  female       1     0
# 3                     NaN             NaN     NaN       0     0
# 4                   193.0          3450.0  female       1     0

# %%
pinguin.drop(['sexo'], axis=1, inplace=True)
pinguin
# Out:
#         Espece       Ilha  largura do bico  profundidade do bico  \
# 0       Adelie  Torgersen             39.1                  18.7
# 1       Adelie  Torgersen             39.5                  17.4
# 2       Adelie  Torgersen             40.3                  18.0
# 3       Adelie  Torgersen              NaN                   NaN
# 4       Adelie  Torgersen             36.7                  19.3
# ..         ...        ...              ...                   ...
# 339  Chinstrap      Dream             55.8                  19.8
# 340  Chinstrap      Dream             43.5                  18.1
# 341  Chinstrap      Dream             49.6                  18.2
# 342  Chinstrap      Dream             50.8                  19.0
# 343  Chinstrap      Dream             50.2                  18.7
#
#      profundidade do bico.1  massa corporal  female  male
# 0                     181.0          3750.0       0     1
# 1                     186.0          3800.0       1     0
# ...
